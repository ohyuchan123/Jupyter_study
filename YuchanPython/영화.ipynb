# %%
#네이버 영화ㅏ 순위 크롤링
import pandas as pd
import numpy as np

url = 'https://movie.naver.com/movie/sdb/rank/rmovie.naver'
ranking = pd.read_html(url, encoding="utf-8")[0]
ranking
# Out:
#     순위                       영화명  변동폭  변동폭.1  Unnamed: 4  Unnamed: 5  \
# 0  NaN                       NaN  NaN    NaN         NaN         NaN
# 1  NaN                  스즈메의 문단속  NaN    0.0         NaN         NaN
# 2  NaN                       대외비  NaN    0.0         NaN         NaN
# 3  NaN  귀멸의 칼날: 상현집결, 그리고 도공 마을로  NaN    0.0         NaN         NaN
# 4  NaN                      서치 2  NaN    0.0         NaN         NaN
# 5  NaN                       똑똑똑  NaN    1.0         NaN         NaN
# 6  NaN                더 퍼스트 슬램덩크  NaN    1.0         NaN         NaN
# 7  NaN                       멍뭉이  NaN    0.0         NaN         NaN
# 8  NaN           앤트맨과 와스프: 퀀텀매니아  NaN    0.0         NaN         NaN
# 9  NaN              아임 히어로 더 파이널  NaN    0.0         NaN         NaN
# 10 NaN                        살수  NaN    0.0         NaN         NaN
# 11 NaN                       NaN  NaN    NaN         NaN         NaN
# 12 NaN                       카운트  NaN    0.0         NaN         NaN
# 13 NaN                      파벨만스  NaN    2.0         NaN         NaN
# 14 NaN                     소울메이트  NaN    0.0         NaN         NaN
# 15 NaN                      더 웨일  NaN    2.0         NaN         NaN
# 16 NaN                샤잠! 신들의 분노  NaN    2.0         NaN         NaN
# 17 NaN                   마루이 비디오  NaN    0.0         NaN         NaN
# 18 NaN                       웅남이  NaN    NaN         NaN         NaN
# 19 NaN                      6번 칸  NaN    1.0         NaN         NaN
# 20 NaN                       플레인  NaN    NaN         NaN         NaN
# 21 NaN                       NaN  NaN    NaN         NaN         NaN
#
#     Unnamed: 6  Unnamed: 7
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN
# 5          NaN         NaN
# 6          NaN         NaN
# 7          NaN         NaN
# 8          NaN         NaN
# 9          NaN         NaN
# 10         NaN         NaN
# 11         NaN         NaN
# 12         NaN         NaN
# 13         NaN         NaN
# 14         NaN         NaN
# 15         NaN         NaN
# 16         NaN         NaN
# 17         NaN         NaN
# 18         NaN         NaN
# 19         NaN         NaN
# 20         NaN         NaN
# 21         NaN         NaN

# %%
len(ranking)
# Out:
# 22

# %%
ranking[ranking["영화명"].notnull()]
# Out:
#     순위                       영화명  변동폭  변동폭.1  Unnamed: 4  Unnamed: 5  \
# 1  NaN                  스즈메의 문단속  NaN    0.0         NaN         NaN
# 2  NaN                       대외비  NaN    0.0         NaN         NaN
# 3  NaN  귀멸의 칼날: 상현집결, 그리고 도공 마을로  NaN    0.0         NaN         NaN
# 4  NaN                      서치 2  NaN    0.0         NaN         NaN
# 5  NaN                       똑똑똑  NaN    1.0         NaN         NaN
# 6  NaN                더 퍼스트 슬램덩크  NaN    1.0         NaN         NaN
# 7  NaN                       멍뭉이  NaN    0.0         NaN         NaN
# 8  NaN           앤트맨과 와스프: 퀀텀매니아  NaN    0.0         NaN         NaN
# 9  NaN              아임 히어로 더 파이널  NaN    0.0         NaN         NaN
# 10 NaN                        살수  NaN    0.0         NaN         NaN
# 12 NaN                       카운트  NaN    0.0         NaN         NaN
# 13 NaN                      파벨만스  NaN    2.0         NaN         NaN
# 14 NaN                     소울메이트  NaN    0.0         NaN         NaN
# 15 NaN                      더 웨일  NaN    2.0         NaN         NaN
# 16 NaN                샤잠! 신들의 분노  NaN    2.0         NaN         NaN
# 17 NaN                   마루이 비디오  NaN    0.0         NaN         NaN
# 18 NaN                       웅남이  NaN    NaN         NaN         NaN
# 19 NaN                      6번 칸  NaN    1.0         NaN         NaN
# 20 NaN                       플레인  NaN    NaN         NaN         NaN
#
#     Unnamed: 6  Unnamed: 7
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN
# 5          NaN         NaN
# 6          NaN         NaN
# 7          NaN         NaN
# 8          NaN         NaN
# 9          NaN         NaN
# 10         NaN         NaN
# 12         NaN         NaN
# 13         NaN         NaN
# 14         NaN         NaN
# 15         NaN         NaN
# 16         NaN         NaN
# 17         NaN         NaN
# 18         NaN         NaN
# 19         NaN         NaN
# 20         NaN         NaN

# %%
ranking = ranking[ranking["영화명"].notnull()]

# %%
ranking["순위"] = np.arange(1,51)
ranking
# Out:
#     순위               영화명  변동폭  변동폭.1  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 1    1                인질  NaN    0.0         NaN         NaN         NaN
# 2    2              모가디슈  NaN    0.0         NaN         NaN         NaN
# 3    3      샹치와 텐 링즈의 전설  NaN    2.0         NaN         NaN         NaN
# 4    4             레미니센스  NaN    1.0         NaN         NaN         NaN
# 5    5               싱크홀  NaN    1.0         NaN         NaN         NaN
# 6    6                귀신  NaN    0.0         NaN         NaN         NaN
# 7    7             프리 가이  NaN    1.0         NaN         NaN         NaN
# 8    8            여름날 우리  NaN    1.0         NaN         NaN         NaN
# 9    9                귀문  NaN    0.0         NaN         NaN         NaN
# 10  10                올드  NaN    0.0         NaN         NaN         NaN
# 12  11        맨 인 더 다크 2  NaN    2.0         NaN         NaN         NaN
# 13  12             최선의 삶  NaN    4.0         NaN         NaN         NaN
# 14  13       더 수어사이드 스쿼드  NaN    2.0         NaN         NaN         NaN
# 15  14            그린 나이트  NaN    2.0         NaN         NaN         NaN
# 16  15                코다  NaN    2.0         NaN         NaN         NaN
# 17  16          습도 다소 높음  NaN   14.0         NaN         NaN         NaN
# 18  17              바쿠라우  NaN    5.0         NaN         NaN         NaN
# 19  18        건파우더 밀크셰이크  NaN    3.0         NaN         NaN         NaN
# 20  19               데미지  NaN    5.0         NaN         NaN         NaN
# 21  20            블랙 위도우  NaN    1.0         NaN         NaN         NaN
# 23  21     스파이더맨: 노 웨이 홈  NaN    6.0         NaN         NaN         NaN
# 24  22              스틸워터  NaN    4.0         NaN         NaN         NaN
# 25  23              이터널스  NaN    3.0         NaN         NaN         NaN
# 26  24                자마  NaN   22.0         NaN         NaN         NaN
# 27  25  베놈 2: 렛 데어 비 카니지  NaN    1.0         NaN         NaN         NaN
# 28  26       퍼피 구조대 더 무비  NaN    3.0         NaN         NaN         NaN
# 29  27                랑종  NaN    2.0         NaN         NaN         NaN
# 30  28     꽃다발 같은 사랑을 했다  NaN    1.0         NaN         NaN         NaN
# 31  29            날씨의 아이  NaN    3.0         NaN         NaN         NaN
# 32  30              켈리 갱  NaN    2.0         NaN         NaN         NaN
# 34  31               보이스  NaN    5.0         NaN         NaN         NaN
# 35  32          디스 아메리카노  NaN    3.0         NaN         NaN         NaN
# 36  33  스네이크 아이즈: 지.아이.조  NaN    7.0         NaN         NaN         NaN
# 37  34            팜 스프링스  NaN    7.0         NaN         NaN         NaN
# 38  35                밥정  NaN    4.0         NaN         NaN         NaN
# 39  36                기적  NaN    7.0         NaN         NaN         NaN
# 40  37           너의 이름은.  NaN   12.0         NaN         NaN         NaN
# 41  38           소셜 네트워크  NaN   16.0         NaN         NaN         NaN
# 42  39              그린 북  NaN    2.0         NaN         NaN         NaN
# 43  40  조제, 호랑이 그리고 물고기들  NaN    4.0         NaN         NaN         NaN
# 45  41           방법: 재차의  NaN    6.0         NaN         NaN         NaN
# 46  42               캔디맨  NaN    3.0         NaN         NaN         NaN
# 47  43          보스 베이비 2  NaN   10.0         NaN         NaN         NaN
# 48  44              암살자들  NaN    7.0         NaN         NaN         NaN
# 49  45            생각의 여름  NaN    7.0         NaN         NaN         NaN
# 50  46              잘리카투  NaN    1.0         NaN         NaN         NaN
# 51  47                 듄  NaN    8.0         NaN         NaN         NaN
# 52  48                반도  NaN   20.0         NaN         NaN         NaN
# 53  49              크루엘라  NaN   11.0         NaN         NaN         NaN
# 54  50               스피릿  NaN    8.0         NaN         NaN         NaN
#
#     Unnamed: 7
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
# 30         NaN
# 31         NaN
# 32         NaN
# 34         NaN
# 35         NaN
# 36         NaN
# 37         NaN
# 38         NaN
# 39         NaN
# 40         NaN
# 41         NaN
# 42         NaN
# 43         NaN
# 45         NaN
# 46         NaN
# 47         NaN
# 48         NaN
# 49         NaN
# 50         NaN
# 51         NaN
# 52         NaN
# 53         NaN
# 54         NaN

# %%
# Out:
# <ipython-input-30-33ca694dbd8f>:1: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   df_movies[["순위","영화명","변동폭.1"]]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-33ca694dbd8f> in <module>
# ----> 1 df_movies[["순위","영화명","변동폭.1"]]
#       2 df_movies
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
