# %%
import pandas as pd
import numpy as np
url='https://ko.wikipedia.org/wiki/%EB%84%B7%ED%94%8C%EB%A6%AD%EC%8A%A4'
moive = pd.read_html(url, encoding="utf-8")[0]
moive
# Out:
#                          0                                                  1
# 0   넷플릭스 주식회사Netflix, Inc.                             넷플릭스 주식회사Netflix, Inc.
# 1                      NaN                                                NaN
# 2                       형태                                              상장 기업
# 3                    산업 분야                                            OTT 서비스
# 4                       창립                    미국 1997년 8월 29일대한민국 2016년 1월 7일
# 5                      창립자                                     리드 헤이스팅스마크 랜돌프
# 6                    시장 정보                            나스닥: NFLX S&P 500 구성 기업
# 7                       국가                                                 미국
# 8                   본사 소재지                                        캘리포니아 로스가토스
# 9                    사업 지역                                         190개 국가[1]
# 10                   핵심 인물  리드 헤이스팅스 (회장, 공동CEO)테드 서랜도스 (공동CEO, CCO)그레그 피터...
# ...

# %%
len(movie)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-6120a3ffe974> in <module>
# ----> 1 len(movie)
#
# NameError: name 'movie' is not defined
